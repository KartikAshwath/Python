# %%
import matplotlib.pyplot as plt

# %%
x=[1,3,5,7,8]
y=[2,4,1,8,10]

# %%
plt.scatter(x,y,label='skitscat',color='g')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Scater_Plot')
plt.legend()
plt.show()
